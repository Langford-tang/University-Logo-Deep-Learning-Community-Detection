# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('./1.jpeg')

# %%
img.getchannel('R')
# Out:
# <PIL.Image.Image image mode=L size=199x254 at 0x7FAB87090438>

# %%
img.getchannel('G')
# Out:
# <PIL.Image.Image image mode=L size=199x254 at 0x7FAB87090208>

# %%
plt.imshow(img)

# %%
r, g, b = img.split()

# %%
import os

# %%
os.chdir('./sample')

# %%
os.chdir('../Japan')
names = sample(os.listdir(), 20)
#map(lambda x : os.remove(x), names)
for item in names:
    os.remove(item)

# %%
from random import sample

# %%
os.chdir('../')

# %% [markdown]
# # 取样

# %%
for country in os.listdir():
    if len(os.listdir(country)) > 100:
        os.chdir(country)
        length = len(os.listdir())
        names = sample(os.listdir(), length - 100)
        for item in names:
            os.remove(item)
        os.chdir('../')
